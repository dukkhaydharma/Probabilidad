# %% [markdown]
# # **Probabilidad y estadistica**
#
# # Grupo: 2y
# # Unidad 1
# ## Docente: Jose Gabriel Rodriguez Rivas
# ## Alumno: Carla Iberia Carrillo Ferrer
# ## Practica 1. Medidas de tendencia central e histogramas

# %%
from statistics import *

# %%
# Lista de calififcaciones del grupo a
grupoa = [70, 70, 65, 90, 100, 95, 45, 80,73, 20, 100, 96,]
print(grupoa)

# %%
# La funcion type nos devuelve el tipo de dato de la variable
type(grupoa)
# Out:
# list

# %%
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
#Utilizar la funcion mean que esta en la libreria statistics para
# el promedio
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
# Determinar el valor de la mediana con la funcion median
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
# Determinar el valor de la moda
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
# En caso de que exista mas de una moda, se puede
# Multiples modas que pueden existir.
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %% [markdown]
# Ejemplo 2

# %%
#Definimos
from statistics import *
tiempos100mts = [15.15, 10.17, 10.34, 17.24, 24.21, 22.34, 34.56, 23.45, 13.25, 23.54]

# %%
print("El tiempo promedio de los corredores es=> ", mean (tiempos100mts))
# Out:
# El tiempo promedio de los corredores es=>  19.425

# %%
mediana = median(tiempos100mts)
print("La mediana de los tiempos de los corredores es: ")
print(mediana)
# Out:
# La mediana de los tiempos de los corredores es:
# 19.79

# %%
moda = mode(tiempos100mts)
print("La moda de los tiempos es =>", moda)
# Out:
# La moda de los tiempos es => 15.15

# %%
multimodas= multimode(tiempos100mts)
print("La multimoda de los tiempos es =>", multimodas)
# Out:
# La multimoda de los tiempos es => [15.15, 10.17, 10.34, 17.24, 24.21, 22.34, 34.56, 23.45, 13.25, 23.54]

# %%
# Libreria para generar numeros aleatorios
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio  = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [98.67, 88.39, 88.88, 55.0, 94.55, 97.06, 80.41, 86.06, 63.03, 53.42, 90.86, 65.32, 96.61, 71.44, 52.26, 96.3, 84.54, 84.08, 81.23, 53.97, 99.36, 93.79, 53.81, 95.98, 75.36, 56.83, 90.38, 86.1, 99.23, 70.55, 94.22, 76.12, 75.93, 84.97, 83.59, 56.64, 70.55, 99.73, 96.42, 71.73, 70.43, 96.24, 70.92, 76.26, 81.18, 69.96, 55.63, 69.4, 50.3, 89.5, 91.07, 72.18, 52.16, 92.17, 51.04, 87.83, 92.52, 53.38, 99.53, 78.06, 61.22, 74.22, 52.63, 83.34, 63.16, 67.11, 74.64, 54.23, 92.57, 60.7, 67.24, 86.04, 81.66, 85.45, 95.28, 94.28, 61.83, 60.35, 62.58, 53.8, 73.78, 89.64, 55.5, 70.52, 52.13, 83.36, 97.88, 72.31, 67.08, 59.12, 97.79, 97.61, 99.6, 53.22, 86.27, 74.5, 79.82, 95.56, 75.32, 81.41]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio  = round(random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [58.31, 68.42, 73.7, 83.08, 62.24, 70.89, 83.51, 54.3, 70.94, 85.88, 92.99, 62.27, 91.56, 97.14, 77.75, 62.23, 77.06, 56.83, 83.68, 57.05, 90.75, 84.69, 93.25, 98.46, 53.61, 53.94, 97.62, 58.5, 61.1, 94.53, 64.15, 76.11, 90.87, 55.35, 68.93, 64.25, 56.67, 83.13, 89.75, 67.58, 97.15, 92.07, 64.78, 95.28, 77.56, 98.56, 75.42, 92.19, 85.62, 57.73, 94.6, 60.41, 62.75, 94.73, 50.0, 55.59, 78.01, 93.96, 75.39, 81.06, 96.69, 76.69, 71.92, 51.31, 64.5, 69.16, 58.39, 57.79, 98.15, 77.32, 88.5, 72.38, 58.18, 60.76, 54.74, 50.7, 84.29, 88.64, 56.41, 98.43, 73.11, 65.15, 77.44, 61.52, 86.35, 66.17, 60.81, 71.4, 54.69, 88.2, 78.95, 61.9, 83.75, 61.65, 78.08, 59.85, 97.07, 71.93, 68.77, 79.54]

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
import matplotlib.pyplot as plt
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2')

# %%
from statistics import *
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media de la fabrica 1 es=> ", media1)
print("La mediana de la fabrica 1 es=> ", mediana1)
print("La moda de la fabrica 1 es=> ", moda1)
# Out:
# Valores de la fabrica 1
# La media de la fabrica 1 es=>  77.0788
# La mediana de la fabrica 1 es=>  77.16
# La moda de la fabrica 1 es=>  70.55

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Valores de la fabrica 2")
print("La media de la fabrica 2 es=> ", media1)
print("La mediana de la fabrica 2 es=> ", mediana2)
print("La moda de la fabrica 2 es=> ", moda2)
# Out:
# Valores de la fabrica 2
# La media de la fabrica 2 es=>  77.0788
# La mediana de la fabrica 2 es=>  73.405
# La moda de la fabrica 2 es=>  58.31

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label="Mediana")
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel ('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
